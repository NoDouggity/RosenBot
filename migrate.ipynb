# %%
import pymongo
import psycopg2
import keys

""" 
This notebook was written to migrate data from MongoDB to Postgres.
It assumes that the target server is already initialized.
It also assumes you have appropriately configured MongoClient in your environment to connect to the MongoDB deployment
"""

mongo = pymongo.MongoClient(keys.mongodb_cs)
print('Mongo connection')
pgconn = psycopg2.connect(
    host="localhost",
    dbname='caroldb',
    user='postgres',
    password=keys.pg_pwd
)
print('PG connection')

with pgconn.cursor() as pgcur:
    
    insert_query = """
    INSERT INTO linktable (filingname, filingdate, aenumber, attachment, hyperlink)
    VALUES (%s, %s, %s, %s, %s)
    """
    batch_size = 1000
    batch_data = []

    # Loop through linktable in Mongo, inserting batch to PG
    for document in mongo['Transcripts']['linktable'].find():
        filing_name = document.get("FilingName", None)
        filing_date = document.get("FilingDate", None)
        ae_number = document.get("AENumber", None)
        attachment = True if document.get("Attachment") == "Attachment" else False
        hyperlink = document.get("Hyperlink", None)

        batch_data.append((filing_name, filing_date, ae_number, attachment, hyperlink))

        # at batch_size, insert to PG and reset batch
        if len(batch_data) == batch_size:
            pgcur.executemany(insert_query, batch_data)
            pgconn.commit()
            batch_data = []

    # Insert any remaining linktable data that didn't fill final batch
    if batch_data:
        pgcur.executemany(insert_query, batch_data)
        pgconn.commit()

    # prepare insert command for pages
    insert_query = """
    INSERT INTO pages (embedding, page_number, parent_doc, text)
    VALUES (%s, %s, %s, %s)
    """

    # pages is too large to create a mongo cursor covering the whole table
    # instead, we iterate through pages batchwise using the hyperlink/parent_doc as a batch criterion
    for row in mongo['Transcripts']['transcripts'].find(projection={"Hyperlink":1, "_id":0}):
        hyper = row.get('Hyperlink')
        document_name = hyper[hyper.find('KSM2/')+5:]
        print(f'Preparing {document_name}')
        batch_data = []

        for document in mongo['Transcripts']['pages'].find(filter={"parent_doc":document_name}):
            embedding = document.get("embeddings", None)
            page_number = document.get("page_number", None)
            parent_doc = document.get("parent_doc", None)
            text = document.get("text", None)

            batch_data.append((embedding, page_number, parent_doc, text))

        pgcur.executemany(insert_query, batch_data)
        pgconn.commit()

    # prepare insert command for transcripts table
    insert_query = """
    INSERT INTO transcripts (filingname, filingdate, aenumber, attachment, hyperlink, summary)
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    batch_data = []

    for document in mongo['Transcripts']['transcripts'].find():
        filing_name = document.get("FilingName", None)
        filing_date = document.get("FilingDate", None)
        ae_number = document.get("AENumber", None)
        attachment = True if document.get("Attachment") == "Attachment" else False
        hyperlink = document.get("Hyperlink", None)
        summary = document.get("Summaries", None)

        batch_data.append((filing_name, filing_date, ae_number, attachment, hyperlink, summary))

    pgcur.executemany(insert_query, batch_data)
    pgconn.commit()

pgconn.close()
# Out:
# Mongo connection
# PG connection
# Preparing KSM II (Trans17Dec2013-PM1).pdf
# Preparing KSM II (KSM 806 Transcript 25 Feb 2016)_Part1.pdf
# Preparing KSM II (Trans17Jun2019-MERGED).pdf
# Preparing KSM II (TRANS11Dec2015-PM1).pdf
# Preparing KSM II (TRANS19August2013-PM2).pdf
# Preparing KSM II (TRANS12February2013-AM1).pdf
# Preparing KSM II (TRANS21August2013-AM2).pdf
# Preparing KSM II (TRANS10Sept2018-MERGED2).pdf
# Preparing KSM II (KSM 806 Transcript 25 Feb 2016)_Part2.pdf
# Preparing KSM II (TRANS26July2016-AM1).pdf
# Preparing KSM II (TRANS19Oct2017-PM1).pdf
# Preparing KSM II (TRANS30Oct2019-PM-MERGED).pdf
# Preparing KSM II (Trans20Jun2019-MERGED).pdf
# Preparing KSM II (TRANS21Mar2017-AM1).pdf
# Preparing KSM II (TRANS23Jan2020-MERGED).pdf
# Preparing KSM II (806 Transcript 23 MAR 2017).pdf
# Preparing KSM II (TRANS22Feb2016-AM2).pdf
# Preparing KSM II (TRANS11Feb2015)-AM1.pdf
# Preparing 58416-KSM II (803TRANS6Oct2023).pdf
# Preparing 58248-KSM II (TRANS22Sep2023-MERGED).pdf
# Preparing KSM II (TRANS30May2016-AM1).pdf
# Preparing KSM II (TRANS 19October2012-PM2).pdf
# Preparing KSM II (TRANS25Oct2015)-PM.pdf
# Preparing KSM II (TRANS17October2012-AM1).pdf
# Preparing KSM II (TRANS10Dec2015-PM1).pdf
# Preparing KSM II (TRANS16May2017-AM2).pdf
# Preparing KSM II (802Trans21Feb2020).pdf
# Preparing KSM II (806TRANS19Nov2021).pdf
# Preparing KSM II ((TRANS17April2014-AM).pdf
# Preparing KSM II (TRANS22Jul2019-MERGED).pdf
# Preparing 58415-KSM II (803TRANS3Oct2023-MERGED).pdf
# Preparing KSM II (TRANS20August2013-AM2).pdf
# Preparing 58892-KSM II (806TRANS16Nov2023-MERGED).pdf
# Preparing KSM II (TRANS3Nov2021-MERGED).pdf
# Preparing KSM II (TRANS28Oct2015)-AM1.pdf
# Preparing 58413-KSM II (803TRANS25Sep2023-MERGED).pdf
# Preparing KSM II (TRANS22Feb2016-PM2).pdf
# Preparing KSM II (TRANS8Dec2015-PM2).pdf
# Preparing 58867-KSM II (806TRANS14Nov2023-PM-MERGED).pdf
# Preparing KSM II (TRANS26Oct2015)-AM.pdf
# Preparing KSM II (TRANS9Feb2015)-AM.pdf
# Preparing KSM II (TRANS11Dec2015-PM2).pdf
# Preparing KSM II (TRANS8Dec2015-PM1).pdf
# Preparing KSM II (TRANS30Apr2019-MERGED).pdf
# Preparing 59471-KSM II (803TRANS14Feb2024-MERGED).pdf
# Preparing KSM II (TRANS21June2013-PM2).pdf
# Preparing 58758-KSM II (803TRANS10Nov2023-MERGED).pdf
# Preparing KSM II (806TRANS31Oct2019)_Part1.pdf
# Preparing KSM II (TRANS31May2016-AM1).pdf
# Preparing KSM II (TRANS10Dec2015-AM2).pdf
# Preparing KSM II (TRANS12Oct2016-AM1).pdf
# Preparing KSM II (TRANS22Mar2017-PM2).pdf
# Preparing KSM II (TRANS30May2016-PM1).pdf
# Preparing KSM II (TRANS28Oct2015)-AM4.pdf
# Preparing KSM II (TRANS14February2013-PM2).pdf
# Preparing KSM II (TRANS17Nov2021-MERGED).pdf
# Preparing 59501-KSM II (803TRANS19Sept2023-MERGED)v1.pdf
# Preparing KSM II (TRANS8Dec2015-AM1).pdf
# Preparing KSM II (TRANS24Feb2016-AM2).pdf
# Preparing KSM II (806TRANS31Oct2019)_Part4.pdf
# Preparing KSM II (802Trans19Nov2021).pdf
# Preparing 58757-KSM II (803TRANS8Nov2023-MERGED).pdf
# Preparing 59472-KSM II (803TRANS15Feb2024-MERGED).pdf
# Preparing KSM II (TRANS20June2013-PM2).pdf
# Preparing KSM II (TRANS24Mar2017-AM1).pdf
# Preparing KSM II (TRANS16May2017-PM2).pdf
# Preparing KSM II (806TRANS2May2019).pdf
# Preparing KSM II (TRANS20June2013-AM1).pdf
# Preparing KSM II (TRANS20June2013-PM1).pdf
# Preparing KSM II (TRANS16October2012-PM1).pdf
# Preparing KSM II (TRANS8Nov2021-MERGED.pdf
# Preparing 58857-KSM II (803TRANS15Nov2023-MERGED).pdf
# Preparing KSM II (TRANS29Oct2015)-AM1.pdf
# Preparing KSM II (TRANS29Oct2015)-PM1.pdf
# Preparing KSM II (TRANS2May2019-AM).pdf
# Preparing KSM II (TRANS14February2013-AM2).pdf
# Preparing KSM II (TRANS17October2012-PM2).pdf
# Preparing KSM II (TRANS16May2017-PM1).pdf
# Preparing KSM II (806TRANS30Oct2019).pdf
# Preparing KSM II (TRANS25Jan2017-AM1).pdf
# Preparing KSM II (TRANS9Dec2015-AM1).pdf
# Preparing 58856-KSM II (803TRANS14Nov2023-AM-MERGED).pdf
# Preparing KSM II (TRANS25Aug2017-AM2).pdf
# Preparing KSM II (TRANS22Feb2016-PM1).pdf
# Preparing KSM II (TRANS17Feb2016-AM2).pdf
# Preparing KSM II (TRANS4Nov2021-MERGED).pdf
# Preparing KSM II (TRANS16Feb2016-AM).pdf
# Preparing 59537-KSM II (803TRANS20Feb2024-MERGED).pdf
# Preparing KSM II (TRANS25Aug2017-PM).pdf
# Preparing KSM II (TRANS27Jan2020-MERGED)_Part4.pdf
# Preparing KSM II (TRANS17October2012-PM1).pdf
# Preparing 9-11 KSM 806 Transcript 24 MAR 2017.pdf
# Preparing KSM II (TRANS27Jan2020-MERGED)_Part5.pdf
# Preparing KSM II (TRANS27Jan2020-MERGED)_Part1.pdf
# Preparing KSM II (TRANS5May2012-PMpt1).pdf
# Preparing KSM II (TRANS10Dec2015-AM1).pdf
# Preparing KSM II (TRANS24Aug2017-AM2).pdf
# Preparing KSM II (TRANS20Mar2017-AM1).pdf
# Preparing KSM II (TRANS11Jan2018-MERGED).pdf
# Preparing KSM II (TRANS7Sept2021-MERGED).pdf
# Preparing KSM II (TRANS26July2016-PM1).pdf
# Preparing KSM II (TRANS21Jan2020-MERGED).pdf
# Preparing KSM II (TRANS8Sept2021-MERGED).pdf
# Preparing 58378-KSM II (803TRANS18Sep2023-PLACEHOLDER).pdf
# Preparing KSM II (TRANS29January2013-AM1).pdf
# Preparing KSM II (TRANS25Sep2019-MERGED).pdf
# Preparing KSM II (TRANS15May2017-AM3).pdf
# Preparing KSM II (TRANS20Oct2015)-AM.pdf
# Preparing KSM II (806TRANS4Nov2019)-PM2.pdf
# Preparing KSM II (TRANS1Nov2019-MERGED).pdf
# Preparing 59451-KSM II (803TRANS12Feb2024-MERGED).pdf
# Preparing KSM II (TRANS18October2012-AM2).pdf
# Preparing 59572-KSM II (803TRANS26Feb2024-MERGED).pdf
# Preparing KSM II (TRANS2Nov2021-AM).pdf
# Preparing KSM II (TRANS10Nov2021-MERGED).pdf
# Preparing KSM II (TRANS14Aug2014-AM2).pdf
# Preparing KSM II (TRANS12February2013-PM1).pdf
# Preparing KSM II (TRANS7Dec2017-MERGED).pdf
# Preparing KSM II (TRANS22Jan2020-PM-MERGED).pdf
# Preparing KSM II (TRANS17Feb2016-PM).pdf
# Preparing KSM II (TRANS19August2013-AM1).pdf
# Preparing KSM II (TRANS16Oct2017-AM1).pdf
# Preparing KSM II (806TRANS25Jul2019-AM-Part3).pdf
# Preparing KSM II (TRANS19Oct2015)-AM2.pdf
# Preparing KSM II (TRANS20Mar2017-PM1).pdf
# Preparing 58853-KSM II (806TRANS9Nov2023-MERGED).pdf
# Preparing KSM II (TRANS2June2016-AM2).pdf
# Preparing KSM II (TRANS21Mar2017-PM2).pdf
# Preparing KSM II (TRANS11Feb2015)-AM2.pdf
# Preparing KSM II (806TRANS25Jul2019-AM-Part1).pdf
# Preparing KSM II (TRANS29Oct2015)-AM3.pdf
# Preparing KSM II (TRANS16October2012-AM1).pdf
# Preparing KSM II (TRANS16October2012-AM2).pdf
# Preparing KSM II (TRANS7Dec2016-AM2).pdf
# Preparing KSM II (Trans19Jun2019-MERGED).pdf
# Preparing KSM II (TRANS26Sep2019-MERGED).pdf
# Preparing KSM II (TRANS31Jan2020-MERGED).pdf
# Preparing KSM II (TRANS9Nov2021-MERGED).pdf
# Preparing KSM II (TRANS18Dec2013-AM1).pdf
# Preparing KSM II (TRANS5Nov2019 806 MERGED)_Part2.pdf
# Preparing KSM II (TRANS24Feb2016-AM1).pdf
# Preparing KSM II (TRANS6Dec2017-MERGED).pdf
# Preparing KSM II (TRANS6Dec2016-AM2).pdf
# Preparing KSM II (TRANS25Jan2017-AM2).pdf
# Preparing KSM II (806TRANS5Nov2019).pdf
# Preparing KSM II (TRANS18Feb2016-PM1).pdf
# Preparing KSM II (Trans20Feb2020-PM).pdf
# Preparing KSM II (TRANS24Aug2017-PM).pdf
# Preparing KSM II (TRANS28Jan2020-PM-MERGED)_Part1.pdf
# Preparing KSM II (TRANS29Jan2020-MERGED).pdf
# Preparing KSM II (TRANS11Oct2016-AM2).pdf
# Preparing 59538-KSM II (803TRANS21Feb2024-MERGED).pdf
# Preparing KSM II (TRANS6Dec2016-PM2).pdf
# Preparing KSM II (TRANS28January2013-AM1).pdf
# Preparing KSM II (806TRANS4Nov2019)-PM1.pdf
# Preparing KSM II (806TRANS23Sep2019).pdf
# Preparing KSM II (TRANS18Feb2016-AM2).pdf
# Preparing KSM II (TRANS12Oct2016-AM2).pdf
# Preparing KSM II (TRANSApr292019-MERGED).pdf
# Preparing KSM II (806 Transcript 20 Oct 2017)_Part2.pdf
# Preparing KSM II (TRANS26Feb2016-AM2).pdf
# Preparing KSM II (TRANS16June2014-AM2).pdf
# Preparing 58858-KSM II (806TRANS15Nov2023-MERGED).pdf
# Preparing KSM II (TRANS23Sept2019-MERGED).pdf
# Preparing KSM II (TRANS22Feb2016-AM1).pdf
# Preparing KSM II (TRANS28Jan2020-PM-MERGED)_Part2.pdf
# Preparing KSM II (TRANS2June2016-PM).pdf
# Preparing KSM II (806TRANS12Nov2021).pdf
# Preparing KSM II (TRANS1June2016-AM1).pdf
# Preparing KSM II (TRANS22August2013-AM2).pdf
# Preparing KSM II (TRANS20June2013-AM2).pdf
# Preparing KSM II (TRANS18Feb2020-MERGED).pdf
# Preparing KSM II (TRANS21Aug2017-AM1).pdf
# Preparing KSM II (TRANS30Oct2019-AM-MERGED).pdf
# Preparing 58563-KSM II (806TRANS5Oct2023).pdf
# Preparing KSM II (TRANS18Dec2013-PM1).pdf
# Preparing KSM II (TRANS5Nov2021-MERGED.pdf
# Preparing KSM II (TRANS11Feb2020-MERGED).pdf
# Preparing KSM II (TRANS5May2012-AMpt2).pdf
# Preparing KSM II (TRANS20Feb2020-MERGED).pdf
# Preparing KSM II (TRANS21July2016-PM).pdf
# Preparing KSM II (TRANS28Oct2015)-AM2.pdf
# Preparing 58855-KSM II (806TRANS13Nov2023_r2).pdf
# Preparing 58362-KSM II (TRANS27Sept2023-MERGED).pdf
# Preparing KSM II (TRANS5Nov2019 806 MERGED)_Part1.pdf
# Preparing KSM II (TRANS19October2012-AM2).pdf
# Preparing KSM II (TRANS28Jan2020-AM-MERGED)_Part1.pdf
# Preparing KSM II (TRANS31May2016-PM1).pdf
# Preparing KSM_II_(TRANS_15Oct2012-AM2).pdf
# Preparing KSM II (TRANS28January2013-AM2).pdf
# Preparing KSM II (TRANS21June2013-AM).pdf
# Preparing KSM II (TRANS19Oct2015)-AM1.pdf
# Preparing KSM II (TRANS21Mar2017-PM1).pdf
# Preparing KSM II (TRANS18Oct2017-AM2).pdf
# Preparing KSM II (TRANS28Jan2020-AM-MERGED)_Part2.pdf
# Preparing KSM II (TRANS11Dec2015-AM2).pdf
# Preparing KSM II (TRANS26Feb2016-PM).pdf
# Preparing KSM II (TRANS24Feb2016-PM).pdf
# Preparing KSM II (TRANS12Feb2015)-AM1.pdf
# Preparing KSM II (TRANS18June2013-PM1).pdf
# Preparing KSM II (TRANS20August2013-PM1).pdf
# Preparing KSM II (TRANS15May2017-PM1).pdf
# Preparing KSM II (TRANS3June2016-AM).pdf
# Preparing KSM II (TRANS9Dec2015-PM2).pdf
# Preparing KSM II (806TRANS31Oct2019)_Part2.pdf
# Preparing KSM II (TRANS15April2014-AM).pdf
# Preparing KSM II (TRANS20July2016-AM2).pdf
# Preparing KSM II (TRANS30Jan2020-MERGED).pdf
# Preparing KSM II (TRANS11Dec2015-AM1).pdf
# Preparing KSM II (TRANS23Feb2016-AM2).pdf
# Preparing KSM II (TRANS25Oct2015)-AM1.pdf
# Preparing KSM II (TRANS18June2013-AM1).pdf
# Preparing KSM II (TRANS2Nov2021-PM).pdf
# Preparing KSM II (TRANS27Jan2020-MERGED)_Part3.pdf
# Preparing 58859-KSM II (803TRANS16Nov2023-MERGED).pdf
# Preparing 58434-KSM II (806TRANS29Sep2023-MERGED).pdf
# Preparing KSM II (TRANS30Oct2015-PM)1of2.pdf
# Preparing KSM II (806TRANS1Nov2019).pdf
# Preparing KSM II (TRANS7Nov2019-MERGED).pdf
# Preparing KSM II (TRANS19Feb2020-MERGED).pdf
# Preparing KSM II (TRANS10Sept2021-MERGED).pdf
# Preparing KSM II (TRANS18Nov2021-REDACTED).pdf
# Preparing KSM II (TRANS28Oct2019-MERGED).pdf
# Preparing KSM II (TRANS8Nov2019-MERGED).pdf
# Preparing KSM II (TRANS9Dec2015-AM2).pdf
# Preparing KSM II (TRANS9Dec2015-PM1).pdf
# Preparing KSM II (TRANS18Dec2013-PM2).pdf
# Preparing KSM II (TRANS18Dec2013-AM2).pdf
# Preparing KSM II (TRANS11Feb2015)-PM1.pdf
# Preparing KSM II (TRANS14April2014-AM).pdf
# Preparing KSM II (TRANS16June2014-AM1).pdf
# Preparing KSM II (TRANS30Oct2015-AM2).pdf
# Preparing KSM II (TRANS12Feb2015)-AM2.pdf
# Preparing KSM II (TRANS14Aug2014-AM1).pdf
# Preparing KSM II (TRANS17Dec2013-AM).pdf
# Preparing KSM II (TRANS20Sep2013-AM2).pdf
# Preparing KSM II (TRANS20Sep2013-PM2).pdf
# Preparing KSM II (TRANS24Oct2013-AM2).pdf
# Preparing KSM II (TRANS19September2013-PM1).pdf
# Preparing KSM II (TRANS22Oct2013-AM1).pdf
# Preparing KSM II (TRANS23Oct2013-AM2).pdf
# Preparing KSM II (TRANS22Oct2013-PM).pdf
# Preparing KSM II (TRANS23Oct2013-AM1).pdf
# Preparing KSM II (TRANS19September2013-AM1).pdf
# Preparing KSM II (TRANS23Oct2013-PM2).pdf
# Preparing KSM II (TRANS18Sep2013-AM2).pdf
# Preparing KSM II (TRANS23August2013-PM1).pdf
# Preparing KSM II (TRANS16Sep2013-AM).pdf
# Preparing KSM II (TRANS21June2013-PM1).pdf
# Preparing KSM II (TRANS21June2013-PM3).pdf
# Preparing KSM II (TRANS19June2013-AM).pdf
# Preparing KSM II (TRANS21August2013-AM1).pdf
# Preparing KSM II (TRANS23August2013-AM2).pdf
# Preparing KSM II (TRANS21August2013-PM).pdf
# Preparing KSM II (TRANS19August2013-AM2).pdf
# Preparing KSM II (TRANS17June2013-AM1).pdf
# Preparing KSM II (TRANS13February2013-AM2).pdf
# Preparing KSM II (TRANS29January2013-AM2).pdf
# Preparing KSM II (TRANS13February2013-PM2).pdf
# Preparing KSM II (TRANS17June2013-PM2).pdf
# Preparing KSM II (TRANS29January2013-PM1).pdf
# Preparing KSM II (TRANS17June2013-PM1).pdf
# Preparing KSM II (TRANS31January2013-AM2).pdf
# Preparing KSM II (TRANS 15Oct2012-PM).pdf
# Preparing KSM II (TRANS28January2013-PM1).pdf
# Preparing 58296-KSM II (803TRANS10Oct2023-MERGED).pdf
# Preparing 58429-KSM II (803TRANS9Oct2023).pdf
# Preparing 58522-KSM II (806TRANS3Oct2023-MERGED).pdf
# Preparing KSM II (TRANS 15Oct2012-AM1).pdf
# Preparing KSM II (TRANS5May2012-PMpt3).pdf
# Preparing KSM II (TRANS5May2012-AM).pdf
# Preparing 58651-KSM II (803TRANS11Oct2023_v2).pdf
# Preparing 58379-KSM II (806TRANS10Oct2023-PM MERGED).pdf
# Preparing 58562-KSM II (806TRANS4Oct2023).pdf
# Preparing 58435-KSM II (803TRANS5Oct2023-MERGED).pdf
# Preparing KSM II (TRANS13Sept2021-MERGED).pdf
# Preparing 58428-KSM II (806TRANS28Sept2023-MERGED).pdf
# Preparing 58414-KSM II (803TRANS2Oct2023-MERGED).pdf
# Preparing 58363-KSM II (803TRANS28Sept2023-MERGED).pdf
# Preparing 58216-KSM II (803TRANS29Sep2023-MERGED).pdf
# Preparing 58361-KSM II (TRANS26Sept2023-MERGED).pdf
# Preparing KSM II (TRANS22Jan2020-AM-MERGED).pdf
# Preparing KSM II (TRANS27Jan2020-MERGED)_Part2.pdf
# Preparing KSM II (TRANS28Jan2020-PM-MERGED)_Part3.pdf
# Preparing KSM II (TRANS24Jan2020-MERGED).pdf
# Preparing KSM II (806TRANS4Nov2019)-AM.pdf
# Preparing KSM II (TRANS29Oct2019-MERGED).pdf
# Preparing KSM II (806TRANS8Nov2019).pdf
# Preparing KSM II (TRANS6Nov2019-MERGED).pdf
# Preparing KSM II (TRANS24Sep2019-MERGED).pdf
# Preparing KSM II (806TRANS6Nov2019).pdf
# Preparing KSM II (806TRANS31Oct2019)_Part3.pdf
# Preparing KSM II (806TRANS25Sep2019).pdf
# Preparing KSM II (806TRANS20Sep2019-AM).pdf
# Preparing KSM II (TRANS20Sept2019-MERGED).pdf
# Preparing KSM II (806TRANS20Sep2019-PM).pdf
# Preparing KSM II (TRANS19Sept2019-MERGED).pdf
# Preparing KSM II (TRANS16Sep2019-MERGED).pdf
# Preparing KSM II (TRANS17Sept2019-MERGED).pdf
# Preparing KSM II (TRANS11Sep2019-MERGED).pdf
# Preparing KSM II (TRANS12Sep2019-MERGED).pdf
# Preparing KSM II (TRANS9Sep2019-MERGED).pdf
# Preparing KSM II (806TRANS12Sep2019).pdf
# Preparing KSM II (806TRANS19Sep2019).pdf
# Preparing KSM II (TRANS18Sept2019-MERGED).pdf
# Preparing KSM II (TRANS26Jul2019-MERGED).pdf
# Preparing KSM II (TRANS25Jul2019-MERGED).pdf
# Preparing KSM II (806TRANS25Jul2019-PM).pdf
# Preparing KSM II (806TRANSMar262019)_Part2.pdf
# Preparing KSM II (TRANS24Jul2019-MERGED).pdf
# Preparing KSM II (806TRANS21Jun2019).pdf
# Preparing KSM II (806TRANSMar262019)_Part1.pdf
# Preparing KSM II (TRANS21Jun2019-MERGED).pdf
# Preparing KSM II (806TRANS25Jul2019-AM-Part2).pdf
# Preparing KSM II (TRANS27Mar2019-MERGED).pdf
